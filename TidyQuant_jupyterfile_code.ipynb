# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
firstdataset=pd.read_csv('Sales Sample Data.csv')

# %%
firstdataset
# Out:
#       TRANS POSTED DATE TRANS ACTUAL DATE  TRANS POSTED YEAR  \
# 0              6/1/2018          6/1/2018               2018
# 1              6/1/2018          6/1/2018               2018
# 2              6/1/2018          6/1/2018               2018
# 3              6/6/2018          6/6/2018               2018
# 4              6/9/2018          6/9/2018               2018
# 5             6/10/2018         6/10/2018               2018
# 6             6/15/2018         6/15/2018               2018
# 7             6/15/2018         6/15/2018               2018
# 8             6/15/2018         6/15/2018               2018
# 9             6/16/2018         6/16/2018               2018
# 10            6/18/2018         6/18/2018               2018
# 11            6/19/2018          6/2/2018               2018
# 12            6/19/2018         6/19/2018               2018
# 13            6/23/2018         6/23/2018               2018
# ...

# %%
sns.heatmap(firstdataset.isnull(),yticklabels=False,cbar=False,cmap='viridis')
#means there are no null values (cmap=viridis/yellow colour of null values )

# %%
#Finding correlation between the numerical columns
firstdataset.corr(method ='pearson')
# Out:
#                     TRANS POSTED YEAR  TRANS POSTED MONTH  TRANS POSTED DAY  \
# TRANS POSTED YEAR                 NaN                 NaN               NaN
# TRANS POSTED MONTH                NaN            1.000000          0.109492
# TRANS POSTED DAY                  NaN            0.109492          1.000000
# TRANS POSTED WK                   NaN           -0.028360         -0.347564
# TRANS ACTUAL YEAR                 NaN                 NaN               NaN
# TRANS ACTUAL MONTH                NaN            0.999956          0.109968
# TRANS ACTUAL DAY                  NaN            0.112606          0.645312
# TRANS ACTUAL WK                   NaN            0.758169          0.081545
# INVOICED UNITS                    NaN            0.025568          0.010293
# CREDIT MEMO UNITS                 NaN           -0.008639          0.005144
# NET SALES UNITS                   NaN            0.024881          0.010552
# ...

# %%
seconddataset=pd.read_csv('ITEM_MERCH_MASTERFILE_TestData.csv')
seconddataset
# Out:
#                SKU      CATEGORY COLLECTION    LINE_UP ENTRY_DATE CATEGORY.1  \
# 0      AE1242-0103    ENTRYPRICE     FH2015     PMDOWN     2015-7    LOWLINE
# 1      AE1242-0903    ENTRYPRICE     SS2018  CARRYOVER        NaN    LOWLINE
# 2      AE1242-1216    ENTRYPRICE     FH2015  CARRYOVER     2015-7    LOWLINE
# 3      AE1243-0103    ENTRYPRICE     FH2015  CARRYOVER     2015-7    LOWLINE
# 4      AE1243-1216    ENTRYPRICE     FH2015  CARRYOVER     2015-7    LOWLINE
# 5      AE1244-0103    ENTRYPRICE     FH2015     PMDOWN     2015-7    LOWLINE
# 6      AE1244-1216    ENTRYPRICE     FH2015     PMDOWN     2015-7    LOWLINE
# 7      AE1245-0103    ENTRYPRICE     FH2015     PMDOWN     2015-7    LOWLINE
# 8      AE1245-1216    ENTRYPRICE     FH2015     PMDOWN     2015-7    LOWLINE
# 9      AE1246-0102    ENTRYPRICE     FH2015     PMDOWN     2015-7    LOWLINE
# 10     AE1246-0114    ENTRYPRICE     FH2015     PMDOWN     2015-7    LOWLINE
# ...

# %%
sns.heatmap(seconddataset.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
#USED TO REMOVE ANY COLUMN
#seconddataset.drop('name_of_colm',axis=1,inplace=True)
seconddataset.dropna(inplace=True)

# %% [markdown]
# #After removing of null values
# #there are no yellow lines means all the null values are removed

# %%
sns.heatmap(seconddataset.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
plt.figure(figsize=(10, 4))
sns.set_style('whitegrid')
sns.countplot(x='BRAND',hue='GENDER',data=seconddataset,palette='RdBu_r')
#we can easily see that among Brand A,B,C is Brand C is most selled among males,female,unisex,fkids

# %%
plt.figure(figsize=(10, 4))
sns.set_style('whitegrid')
sns.countplot(x='BRAND',hue='CASE SHAPE',data=seconddataset,palette='RdBu_r')

# %%
plt.figure(figsize=(15,6))
sns.set_style('whitegrid')
sns.countplot(x='BRAND',hue='DIAL COLOR',data=seconddataset,palette='rainbow')

# %%
plt.figure(figsize=(8, 4))
sns.set_style('whitegrid')
sns.countplot(x='BRAND',hue='DIAL TYPE',data=seconddataset,palette='rainbow')

# %%
plt.figure(figsize=(10, 6))
sns.set_style('whitegrid')
sns.countplot(x='BRAND',hue='CASE MATERIAL',data=seconddataset,palette='RdBu_r')

# %%
plt.figure(figsize=(10, 4))
sns.set_style('whitegrid')
sns.countplot(x='DIAL TYPE',hue='STRAP TYPE',data=seconddataset,palette='rainbow')

# %%
plt.figure(figsize=(10, 6))
sns.set_style('whitegrid')
sns.countplot(x='CASE MATERIAL',hue='DIAL TYPE',data=seconddataset,palette='rainbow')
#brass is most used case material

# %%
plt.figure(figsize=(18, 4))
sns.set_style('whitegrid')
sns.countplot(x='LOCATION CODE',hue='BRAND',data=firstdataset,palette='rainbow')

# %%
plt.figure(figsize=(16, 4))
sns.distplot(seconddataset['SKU TYPE'],kde=False,color='darkred',bins=60)
#shows normal distribution of data

# %%
sns.set_style('whitegrid')
sns.countplot(x='SKU TYPE',data=seconddataset,palette='RdBu_r')

# %%
plt.figure(figsize=(16, 4))
sns.countplot(x='TECHNOLOGY',data=seconddataset)
#3H is most used technology in watches

# %%
plt.figure(figsize=(15, 4))
sns.boxplot(x='BRAND',y='SKU TYPE',data=seconddataset,palette='RdBu_r')

# %%
seconddataset.head()
# Out:
#            SKU    CATEGORY COLLECTION    LINE_UP ENTRY_DATE CATEGORY.1 GENDER  \
# 0  AE1242-0103  ENTRYPRICE     FH2015     PMDOWN     2015-7    LOWLINE   MALE
# 2  AE1242-1216  ENTRYPRICE     FH2015  CARRYOVER     2015-7    LOWLINE   MALE
# 3  AE1243-0103  ENTRYPRICE     FH2015  CARRYOVER     2015-7    LOWLINE   MALE
# 4  AE1243-1216  ENTRYPRICE     FH2015  CARRYOVER     2015-7    LOWLINE   MALE
# 5  AE1244-0103  ENTRYPRICE     FH2015     PMDOWN     2015-7    LOWLINE   MALE
#
#   CASE MATERIAL CASE COLOR CASE SHAPE  ... DIAL TYPE DIAL COLOR SKU TYPE  \
# 0            SS        SLV      ROUND  ...    ANALOG        SLV        6
# 2            SS        GLD      ROUND  ...    ANALOG        GLD        1
# 3            SS        SLV      ROUND  ...    ANALOG        SLV        0
# 4            SS        GLD      ROUND  ...    ANALOG        GLD        0
# 5            SS        SLV      ROUND  ...    ANALOG        SLV        6
#
# ...

# %%
#correlation between columns
seconddataset.corr(method ='pearson')
# Out:
#                 SKU TYPE  ORIGINAL PRICE  ITEM DISC
# SKU TYPE        1.000000       -0.070223   0.414115
# ORIGINAL PRICE -0.070223        1.000000  -0.152321
# ITEM DISC       0.414115       -0.152321   1.000000

# %%
x=firstdataset.iloc[:,9].values
y=firstdataset.iloc[:,19].values
x,y
# Out:
# (array([22, 22, 22, ...,  1,  1,  1], dtype=int64),
#  array([6552.  , 5243.  , 4257.36, ..., 2719.99, 2590.16, 5386.11]))

# %%
# plt.hist( x,bins=100,color = 'green')
# plt.title('price of article corresponding to date')
# plt.xlabel('n ')
# plt.ylabel('invoiced amount')
# plt.show()

# %%
firstdataset.describe()
# Out:
#        TRANS POSTED YEAR  TRANS POSTED MONTH  TRANS POSTED DAY  \
# count            14386.0        14386.000000      14386.000000
# mean              2018.0            9.583345         23.517239
# std                  0.0            2.184958          8.557659
# min               2018.0            6.000000          1.000000
# 25%               2018.0            8.000000         18.000000
# 50%               2018.0           10.000000         27.000000
# 75%               2018.0           12.000000         31.000000
# max               2018.0           12.000000         31.000000
#
#        TRANS POSTED WK  TRANS ACTUAL YEAR  TRANS ACTUAL MONTH  \
# count     14386.000000            14386.0        14386.000000
# mean         31.904977             2018.0            9.582928
# std          16.496804                0.0            2.184592
# min           1.000000             2018.0            6.000000
# 25%          26.000000             2018.0            8.000000
# ...

# %%
firstdataset.nunique()
#no of unique elements in each column
# Out:
# TRANS POSTED DATE       214
# TRANS ACTUAL DATE       215
# TRANS POSTED YEAR         1
# TRANS POSTED MONTH        7
# TRANS POSTED DAY         31
# TRANS POSTED WK          32
# TRANS ACTUAL YEAR         1
# TRANS ACTUAL MONTH        7
# TRANS ACTUAL DAY         31
# TRANS ACTUAL WK          32
# TRANS TYPE                2
# TRANS DOC NUMBER       2499
# LOCATION CODE            14
# BRAND                     3
# SKU                    1186
# INVOICED UNITS           17
# CREDIT MEMO UNITS         3
# NET SALES UNITS          17
# UNIT PRICE              267
# INVOICED AMOUNT        7520
# SALES ACTIVITY CODE      41
# dtype: int64

# %%
firstdataset.isnull().values.any()
#means there are no missing value
# Out:
# False

# %%
firstdataset.isnull().sum()
# Out:
# TRANS POSTED DATE      0
# TRANS ACTUAL DATE      0
# TRANS POSTED YEAR      0
# TRANS POSTED MONTH     0
# TRANS POSTED DAY       0
# TRANS POSTED WK        0
# TRANS ACTUAL YEAR      0
# TRANS ACTUAL MONTH     0
# TRANS ACTUAL DAY       0
# TRANS ACTUAL WK        0
# TRANS TYPE             0
# TRANS DOC NUMBER       0
# LOCATION CODE          0
# BRAND                  0
# SKU                    0
# INVOICED UNITS         0
# CREDIT MEMO UNITS      0
# NET SALES UNITS        0
# UNIT PRICE             0
# INVOICED AMOUNT        0
# SALES ACTIVITY CODE    0
# dtype: int64

# %%
firstdataset['UNIT PRICE'].fillna(0, inplace=True)
# FILL NULL VALUES WITH 0

# %%
firstdataset['UNIT PRICE']
# Out:
# 0         8190
# 1         7490
# 2         7290
# 3         7590
# 4        10990
# 5         8590
# 6         6790
# 7         5690
# 8         7390
# 9         7790
# 10        5790
# 11        3645
# 12        8590
# 13        5790
# 14        8590
# 15        5790
# 16        2995
# 17        7390
# 18        9490
# 19        9490
# 20        9490
# 21        6790
# 22        2995
# 23        7990
# 24        4690
# 25        6850
# 26        7390
# 27        8590
# 28        4690
# 29        5790
#          ...
# 14356     2240
# 14357     2930
# 14358     4290
# 14359     1990
# 14360     4050
# 14361     3790
# 14362     3000
# 14363     3690
# 14364     2390
# 14365     2390
# 14366     3350
# 14367     1990
# 14368     1740
# 14369     2140
# 14370     1990
# 14371     3390
# 14372     3290
# 14373     3790
# 14374     7190
# 14375     3000
# 14376     2440
# 14377     4190
# 14378     8890
# 14379     5690
# 14380     3140
# 14381     4490
# 14382     3790
# ...

# %%
df_new=firstdataset.dropna()

# %%
df_new
# Out:
#       TRANS POSTED DATE TRANS ACTUAL DATE  TRANS POSTED YEAR  \
# 0              6/1/2018          6/1/2018               2018
# 1              6/1/2018          6/1/2018               2018
# 2              6/1/2018          6/1/2018               2018
# 3              6/6/2018          6/6/2018               2018
# 4              6/9/2018          6/9/2018               2018
# 5             6/10/2018         6/10/2018               2018
# 6             6/15/2018         6/15/2018               2018
# 7             6/15/2018         6/15/2018               2018
# 8             6/15/2018         6/15/2018               2018
# 9             6/16/2018         6/16/2018               2018
# 10            6/18/2018         6/18/2018               2018
# 11            6/19/2018          6/2/2018               2018
# 12            6/19/2018         6/19/2018               2018
# 13            6/23/2018         6/23/2018               2018
# ...

# %%
df_new.groupby(by=['LOCATION CODE','BRAND','SKU'], as_index=False)['SALES ACTIVITY CODE'].count().head()
# Out:
#   LOCATION CODE    BRAND     SKU  SALES ACTIVITY CODE
# 0         Loc 1  Brand C  T18581                    2
# 1         Loc 1  Brand C  T20041                    1
# 2         Loc 1  Brand C  T20071                    1
# 3         Loc 1  Brand C  T20441                    4
# 4         Loc 1  Brand C  T21693                    3

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14386 entries, 0 to 14385
# Data columns (total 21 columns):
# TRANS POSTED DATE      14386 non-null object
# TRANS ACTUAL DATE      14386 non-null object
# TRANS POSTED YEAR      14386 non-null int64
# TRANS POSTED MONTH     14386 non-null int64
# TRANS POSTED DAY       14386 non-null int64
# TRANS POSTED WK        14386 non-null int64
# TRANS ACTUAL YEAR      14386 non-null int64
# TRANS ACTUAL MONTH     14386 non-null int64
# TRANS ACTUAL DAY       14386 non-null int64
# TRANS ACTUAL WK        14386 non-null int64
# TRANS TYPE             14386 non-null object
# TRANS DOC NUMBER       14386 non-null object
# LOCATION CODE          14386 non-null object
# BRAND                  14386 non-null object
# SKU                    14386 non-null object
# INVOICED UNITS         14386 non-null int64
# CREDIT MEMO UNITS      14386 non-null int64
# NET SALES UNITS        14386 non-null int64
# UNIT PRICE             14386 non-null int64
# ...

# %%
df_new.describe().round(2)
#gives answer till round two mean mode medium so on...
# Out:
#        TRANS POSTED YEAR  TRANS POSTED MONTH  TRANS POSTED DAY  \
# count            14386.0            14386.00          14386.00
# mean              2018.0                9.58             23.52
# std                  0.0                2.18              8.56
# min               2018.0                6.00              1.00
# 25%               2018.0                8.00             18.00
# 50%               2018.0               10.00             27.00
# 75%               2018.0               12.00             31.00
# max               2018.0               12.00             31.00
#
#        TRANS POSTED WK  TRANS ACTUAL YEAR  TRANS ACTUAL MONTH  \
# count          14386.0            14386.0            14386.00
# mean              31.9             2018.0                9.58
# std               16.5                0.0                2.18
# min                1.0             2018.0                6.00
# 25%               26.0             2018.0                8.00
# ...

# %%
df2_new=seconddataset.dropna()
df2_new
# Out:
#                SKU      CATEGORY COLLECTION    LINE_UP ENTRY_DATE CATEGORY.1  \
# 0      AE1242-0103    ENTRYPRICE     FH2015     PMDOWN     2015-7    LOWLINE
# 2      AE1242-1216    ENTRYPRICE     FH2015  CARRYOVER     2015-7    LOWLINE
# 3      AE1243-0103    ENTRYPRICE     FH2015  CARRYOVER     2015-7    LOWLINE
# 4      AE1243-1216    ENTRYPRICE     FH2015  CARRYOVER     2015-7    LOWLINE
# 5      AE1244-0103    ENTRYPRICE     FH2015     PMDOWN     2015-7    LOWLINE
# 6      AE1244-1216    ENTRYPRICE     FH2015     PMDOWN     2015-7    LOWLINE
# 7      AE1245-0103    ENTRYPRICE     FH2015     PMDOWN     2015-7    LOWLINE
# 8      AE1245-1216    ENTRYPRICE     FH2015     PMDOWN     2015-7    LOWLINE
# 9      AE1246-0102    ENTRYPRICE     FH2015     PMDOWN     2015-7    LOWLINE
# 10     AE1246-0114    ENTRYPRICE     FH2015     PMDOWN     2015-7    LOWLINE
# 11     AE1247-0103    ENTRYPRICE     FH2015     PMDOWN     2015-7    LOWLINE
# ...

# %%
df2_new.groupby(by=['CATEGORY','COLLECTION','BRAND'], as_index=False)['LINE_UP'].count().head()
# Out:
#   CATEGORY COLLECTION    BRAND  LINE_UP
# 0   BASICS     BH2010  Brand C        1
# 1   BASICS     BH2015  Brand C       43
# 2   BASICS     BH2016  Brand C        5
# 3   BASICS     BH2017  Brand C       20
# 4   BASICS     BH2018  Brand C        4

# %%
#shows which brand has max. linup
orders=df2_new.groupby(by=['BRAND'], as_index=False)['LINE_UP'].count()
plt.subplots(figsize=(4,4))
plt.bar(orders.BRAND, orders.LINE_UP,color='green')
plt.xlabel('BRAND')
plt.ylabel('No of line up')
plt.title('Number of linup of different brands')
plt.show()

# %%
df2_new.groupby(by=['BRAND'], as_index=False)['ORIGINAL PRICE'].sum()
# Brand which is has most sale
# Out:
#      BRAND  ORIGINAL PRICE
# 0  Brand A          588750
# 1  Brand B          405030
# 2  Brand C         3577410

# %%
money_spent=df_new.groupby(by=['LOCATION CODE'], as_index=False)['INVOICED AMOUNT '].sum()
mydata=money_spent.sort_values(by='INVOICED AMOUNT ', ascending=False)
#shows that location 18 has maximum sales and top 5 maximum sales areas
mydata
# Out:
#    LOCATION CODE  INVOICED AMOUNT
# 3         Loc 18        6105814.66
# 10         Loc 4        4635060.26
# 0          Loc 1        4442122.30
# 5          Loc 2        3601765.00
# 4         Loc 19        3451377.06
# 12         Loc 8        3297427.37
# 13         Loc 9        3093333.00
# 7         Loc 21        2195319.06
# 6         Loc 20        2047329.13
# 11         Loc 6        1729664.30
# 1         Loc 10         859919.49
# 8         Loc 22         715332.31
# 9          Loc 3         530179.42
# 2         Loc 11         442183.20

# %%
m=mydata['LOCATION CODE']
n=mydata['INVOICED AMOUNT ']

# %%
#same bargraph as below using matplotlib
# plt.subplots(figsize=(12,4))
# plt.bar(m,n,color='green')
# plt.xlabel('Location Name')
# plt.ylabel('Invoiced Amount')
# plt.title('Location Vs the Total Invoiced Amount')

# %%
plt.figure(figsize=(14, 4))
sns.barplot(m,n, data=mydata)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

import warnings
# current version of seaborn generates a bunch of warnings that we'll ignore
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')

import missingno as msno # missing data visualization module for Python


import gc
import datetime


color = sns.color_palette()

# %%
import matplotlib.style
import matplotlib as mpl
group_country_orders = df_new.groupby('BRAND')['INVOICED AMOUNT '].sum()
plt.subplots(figsize=(8,4))
group_country_orders.plot('barh', fontsize=12, color=color[0])
plt.xlabel('Sum of invoiced amount ', fontsize=12)
plt.ylabel('Brand', fontsize=12)
plt.title('Sum of invoiced amount for each Brand', fontsize=12)
plt.show()

# %%
import matplotlib.style
import matplotlib as mpl
group_country_orders = seconddataset.groupby('BRAND')['ORIGINAL PRICE'].sum()
plt.subplots(figsize=(8,4))
group_country_orders.plot('barh', fontsize=12, color=color[0])
plt.xlabel('Sum of original amount ', fontsize=12)
plt.ylabel('Brand', fontsize=12)
plt.title('Sum of original amount for each Brand', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10, 4))
sns.set_style('whitegrid')
sns.countplot(x='TRANS POSTED YEAR',hue='LOCATION CODE',data=firstdataset,palette='rainbow')
